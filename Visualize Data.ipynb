# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from models.data.utils.frame_utils import read_gen

# %%
root = r'C:\Users\caodo\Desktop\TUM\Praktikum Visual Computing\project\data'
name = '006_mustard_bottle.png'
img1 = read_gen(os.path.join(root, 'img_1', name))
img2 = read_gen(os.path.join(root, 'img_2', name))
flow = read_gen(os.path.join(root, 'flow_viz', name))
occ = read_gen(os.path.join(root, 'occlusion', name))

# %%
plt.figure(figsize=(24, 12))

plt.subplot(2, 2, 1)
plt.imshow(img1)
plt.axis('off')

plt.subplot(2, 2, 2)
plt.imshow(img2)
plt.axis('off')

plt.subplot(2, 2, 3)
plt.imshow(flow)
plt.axis('off')

plt.subplot(2, 2, 4)
plt.imshow(occ, cmap='gray')
plt.axis('off')
plt.tight_layout()
plt.show()
