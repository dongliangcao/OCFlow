# %%
from models.lightning_datamodule import DatasetModule
import torch
import yaml
from utils import visualize_occ

# %%
data_module = DatasetModule(root='/home/tnguyen/dataset/mpi-onesample/training',image_size=(64,128), batch_size=1, dataset_name='MpiSintelCleanInpainting', static_occ=False, overfit=True, occlusion_ratio=0.3)
data_module.prepare_data()
data_module.setup()

# %%
train_dataloader = data_module.train_dataloader()

# %%
for j in range(3):
    for batch in train_dataloader:
        img, complete_img, occ = batch
        imgs = torch.cat((img, complete_img), dim=1)
        for i in range(occ.shape[0]):
            visualize_occ(imgs[i], occ[i], occ[i])
